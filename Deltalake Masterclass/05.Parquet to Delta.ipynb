-- %%
%python
df = spark.read.parquet("abfss://labdata@stgdatabricksdelta.dfs.core.windows.net/invoices/invoices_1_100.parquet")
df.write.parquet("abfss://labdata@stgdatabricksdelta.dfs.core.windows.net/invoices/invoices_1_100_v1")
df.write.parquet("abfss://labdata@stgdatabricksdelta.dfs.core.windows.net/invoices/invoices_1_100_v2")

-- %%
convert to delta parquet.`abfss://labdata@stgdatabricksdelta.dfs.core.windows.net/invoices/invoices_1_100_v1`;

-- %%
%python
from delta.tables import DeltaTable
DeltaTable.convertToDelta(spark,"parquet.`abfss://labdata@stgdatabricksdelta.dfs.core.windows.net/invoices/invoices_1_100_v2`")

-- %% [markdown]
-- #### External Tables

-- %%
Drop table if exists deltacatalog.deltadb.invoices_ext;
Create table deltacatalog.deltadb.invoices_ext
location "abfss://labdata@stgdatabricksdelta.dfs.core.windows.net/invoices/invoices_ext"
as
select * from parquet.`abfss://labdata@stgdatabricksdelta.dfs.core.windows.net/invoices/invoices_1_100.parquet`

-- %%
drop table deltacatalog.deltadb.invoices_ext;

-- %%
select * from deltacatalog.deltadb.invoices_sv
