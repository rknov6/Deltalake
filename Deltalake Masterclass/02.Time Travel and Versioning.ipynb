-- %%
create or replace table deltacatalog.deltadb.invoices_ttv
as
select * from parquet.`abfss://labdata@stgdatabricksdelta.dfs.core.windows.net/invoices/invoices_1_100.parquet`

-- %%
select * from deltacatalog.deltadb.invoices_ttv

-- %%
delete from deltacatalog.deltadb.invoices_ttv where customer_id = 1;

-- %%
update deltacatalog.deltadb.invoices_ttv set quantity = 25 where customer_id = 5

-- %%
insert into deltacatalog.deltadb.invoices_ttv
select * from parquet.`abfss://labdata@stgdatabricksdelta.dfs.core.windows.net/invoices/invoices_101_200.parquet`

-- %%
describe history deltacatalog.deltadb.invoices_ttv

-- %%
select * from deltacatalog.deltadb.invoices_ttv version as of 1

-- %%
select * from deltacatalog.deltadb.invoices_ttv TIMESTAMP AS OF '2025-09-20T13:38:50.000+00:00'

-- %%
restore table deltacatalog.deltadb.invoices_ttv to version as of 0

-- %%
select * from deltacatalog.deltadb.invoices_ttv

-- %%
%python
df = spark.read.option("versionAsOf",1).table("deltacatalog.deltadb.invoices_ttv")
df.display()

-- %%
%python
df = spark.read.option("timestampAsOf", '2025-09-20T13:38:50.000+00:00').table("deltacatalog.deltadb.invoices_ttv")
df.display()
