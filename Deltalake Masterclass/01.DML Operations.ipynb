-- %%
drop catalog if exists deltacatalog;
create catalog if not exists deltacatalog;

-- %%
drop schema if exists deltacatalog.deltadb;
create schema if not exists deltacatalog.deltadb;

-- %%
create or replace table deltacatalog.deltadb.invoices
as
select * from parquet.`abfss://labdata@stgdatabricksdelta.dfs.core.windows.net/invoices/invoices_101_200.parquet`;

-- %%
insert into deltacatalog.deltadb.invoices
select * from parquet.`abfss://labdata@stgdatabricksdelta.dfs.core.windows.net/invoices/invoices_1_100.parquet`

-- %%
select * from deltacatalog.deltadb.invoices

-- %%
update deltacatalog.deltadb.invoices
set quantity = 10
where customer_id = 1

-- %%
update deltacatalog.deltadb.invoices
set quantity = 5
where customer_id = 125

-- %%
delete from deltacatalog.deltadb.invoices
where customer_id = 99

-- %%
insert into deltacatalog.deltadb.invoices
select * from parquet.`abfss://labdata@stgdatabricksdelta.dfs.core.windows.net/invoices/invoices_201_99457.parquet`

-- %% [markdown]
-- #### this is for testing git
